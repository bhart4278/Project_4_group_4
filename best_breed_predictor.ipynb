# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from pyspark.sql import SparkSession

# %%
# Initialize Spark Session
# spark = SparkSession.builder \
#     .appName("Dog Breed Prediction") \
#     .getOrCreate() 

# # Load CSV file into a Spark DataFrame
# df = spark.read.csv("akc-data-latest.csv", header=True, inferSchema=True)

# # Show the first few rows
# df.show(5)

# # Print the schema of the DataFrame
# df.printSchema()

# # Convert Spark DataFrame to Pandas DataFrame (if needed for local analysis)
# df_pandas = df.toPandas()

# # Write the DataFrame back to a CSV file (overwrite if exists)
# df.write.csv("output-folder/akc-data-cleaned", header=True, mode="overwrite")

# %%
# Define the file path
file_path = "Resources/akc-data-latest.csv"

# Read the CSV into a Pandas DataFrame
breed_df = pd.read_csv(file_path)

#Give first column a name
breed_df.rename(columns={breed_df.columns[0]: "Dog Breed"}, inplace=True)

#Preview dataframe
breed_df.head()
# Out:
#           Dog Breed                                        description  \
# 0     Affenpinscher  The Affen’s apish look has been described many...
# 1      Afghan Hound  The Afghan Hound is an ancient breed, his whol...
# 2  Airedale Terrier  The Airedale Terrier is the largest of all ter...
# 3             Akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4  Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
#
#                                  temperament popularity  min_height  \
# 0        Confident, Famously Funny, Fearless        148       22.86
# 1  Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2               Friendly, Clever, Courageous         60       58.42
# 3    Courageous, Dignified, Profoundly Loyal         47       60.96
# 4               Affectionate, Loyal, Playful         58       58.42
#
#    max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0       29.21    3.175147    4.535924            12.0            15.0  ...
# 1       68.58   22.679619   27.215542            12.0            15.0  ...
# 2       58.42   22.679619   31.751466            11.0            14.0  ...
# 3       71.12   31.751466   58.967008            10.0            13.0  ...
# 4       63.50   34.019428   38.555351            10.0            14.0  ...
#
#   grooming_frequency_value  grooming_frequency_category shedding_value  \
# 0                      0.6    2-3 Times a Week Brushing            0.6
# 1                      0.8               Daily Brushing            0.2
# 2                      0.6    2-3 Times a Week Brushing            0.4
# 3                      0.8               Daily Brushing            0.6
# 4                      0.6    2-3 Times a Week Brushing            0.6
#
#    shedding_category energy_level_value  energy_level_category  \
# 0           Seasonal                0.6       Regular Exercise
# 1         Infrequent                0.8              Energetic
# 2         Occasional                0.6       Regular Exercise
# 3           Seasonal                0.8              Energetic
# 4           Seasonal                0.8              Energetic
#
#   trainability_value  trainability_category demeanor_value  demeanor_category
# 0                0.8          Easy Training            1.0           Outgoing
# 1                0.2        May be Stubborn            0.2         Aloof/Wary
# 2                1.0        Eager to Please            0.8           Friendly
# 3                1.0        Eager to Please            0.6   Alert/Responsive
# 4                0.4            Independent            0.8           Friendly
#
# [5 rows x 21 columns]

# %%
breed_df.count()
# Out:
# Dog Breed                      277
# description                    277
# temperament                    276
# popularity                     198
# min_height                     277
# max_height                     277
# min_weight                     275
# max_weight                     275
# min_expectancy                 274
# max_expectancy                 274
# group                          277
# grooming_frequency_value       270
# grooming_frequency_category    270
# shedding_value                 257
# shedding_category              257
# energy_level_value             271
# energy_level_category          271
# trainability_value             253
# trainability_category          253
# demeanor_value                 252
# demeanor_category              252
# dtype: int64

# %%
# Count the number of rows that contain any missing (NaN) values
missing_rows_count = breed_df.isna().any(axis=1).sum()
print(f"\nNumber of rows with missing values: {missing_rows_count}")
# Out:
# Number of rows with missing values: 89

# %%
# Drop rows with any missing values
breed_df_cleaned = breed_df.dropna()

# Count the number of rows after dropping
rows_after_dropping = breed_df_cleaned.shape[0]
print(f"\nNumber of rows after dropping missing values: {rows_after_dropping}")
# Out:
# Number of rows after dropping missing values: 188

# %%
#Preview cleaned df after dropping rows with blanks
breed_df_cleaned.head(60)
# Out:
#                          Dog Breed  \
# 0                    Affenpinscher
# 1                     Afghan Hound
# 2                 Airedale Terrier
# 3                            Akita
# 4                 Alaskan Malamute
# 6       American English Coonhound
# 7              American Eskimo Dog
# 8                American Foxhound
# 11  American Staffordshire Terrier
# 12          American Water Spaniel
# 13          Anatolian Shepherd Dog
# 15           Australian Cattle Dog
# 17             Australian Shepherd
# 19              Australian Terrier
# 20                         Azawakh
# 21                          Barbet
# 22                         Basenji
# 24                    Basset Hound
# 26                          Beagle
# 27                  Bearded Collie
# 28                       Beauceron
# 31                Belgian Malinois
# 32                Belgian Sheepdog
# 33                Belgian Tervuren
# 34             Bergamasco Sheepdog
# 35                   Berger Picard
# 36            Bernese Mountain Dog
# 37                    Bichon Frise
# 39         Black and Tan Coonhound
# 40           Black Russian Terrier
# 41                      Bloodhound
# 42              Bluetick Coonhound
# 43                        Boerboel
# 46                   Border Collie
# 47                  Border Terrier
# 48                          Borzoi
# 49                  Boston Terrier
# 50            Bouvier des Flandres
# 51                           Boxer
# 52                  Boykin Spaniel
# 56                          Briard
# 57                        Brittany
# 59                Brussels Griffon
# 60                    Bull Terrier
# 61                         Bulldog
# 62                     Bullmastiff
# 63                   Cairn Terrier
# 64                      Canaan Dog
# 65                      Cane Corso
# 66            Cardigan Welsh Corgi
# 70   Cavalier King Charles Spaniel
# 72                   Cesky Terrier
# 73        Chesapeake Bay Retriever
# 74                       Chihuahua
# 75                 Chinese Crested
# 76                Chinese Shar-Pei
# 77                         Chinook
# 78                       Chow Chow
# 79               Cirneco dell’Etna
# 80                 Clumber Spaniel
#
#                                           description  \
# 0   The Affen’s apish look has been described many...
# 1   The Afghan Hound is an ancient breed, his whol...
# 2   The Airedale Terrier is the largest of all ter...
# 3   Akitas are burly, heavy-boned spitz-type dogs ...
# 4   The Alaskan Malamute stands 23 to 25 inches at...
# 6   Standing as high as 26 inches at the shoulder,...
# 7   The American Eskimo Dog comes in three sizes—s...
# 8   American Foxhounds are sleek, rangy hunters kn...
# 11  AmStaffs are stocky, muscular bull-type terrie...
# 12  American Water Spaniels are muscular midsize g...
# 13  The Anatolian Shepherd Dog stands between 27 a...
# 15  Standing between 17 to 20 inches at the should...
# 17  The Australian Shepherd, the cowboy’s herding ...
# 19  Australian Terriers are small but sturdy, self...
# 20  This ancient hunting hound is so lean and rang...
# 21  The defining characteristic of this rustic, me...
# 22  Basenjis are small, graceful hounds standing 1...
# 24  The Basset Hound stands no higher than 14 inch...
# 26  There are two Beagle varieties: those standing...
# 27  Standing 20 to 22 inches at the shoulder and c...
# 28  Beaucerons are muscular, rugged, and large, st...
# 31  Belgian Malinois are squarely built, proud, an...
# 32  The stirring silhouette of a Belgian Sheepdog ...
# 33  The Belgian Tervuren is characterized by a str...
# 34  Beneath the one-of-a-kind coat is a large, mus...
# 35  You can spot a Berger Picard a mile away thank...
# 36  The Bernese Mountain Dog is a large, sturdy wo...
# 37  A good-size Bichon will stand a shade under a ...
# 39  Black and Tans have an amazingly sensitive nos...
# 40  What’s the word we’re looking for? Imposing? M...
# 41  Bloodhounds are large, substantial dogs standi...
# 42  Blueticks are speedy and compact nocturnal hun...
# 43  There’s a no-frills, no-nonsense quality to th...
# 46  Borders are athletic, medium-sized herders sta...
# 47  Border Terriers, standing from 11 to 16 inches...
# 48  Borzoi are large, elegant sighthounds. A matur...
# 49  Boston Terriers are compact, short-tailed, wel...
# 50  Standing as high as 27.5 inches, with heavy bo...
# 51  A well-made Boxer in peak condition is an awes...
# 52  Boykins are medium-sized spaniels, larger and ...
# 56  Briards are herders known for a wavy coat of e...
# 57  Brittanys are smaller than setters but leggier...
# 59  With this breed, you get a big personality in ...
# 60  Bull Terriers are robust, big-boned terriers w...
# 61  You can’t mistake a Bulldog for any other bree...
# 62  The Bullmastiff isn’t quite as large as his cl...
# 63  The Cairn’s unique qualities, called “Cairnish...
# 64  Canaan Dogs are lean, bushy-tailed dogs standi...
# 65  At nearly 28 inches at the shoulder and often ...
# 66  Long, low-set dogs with sturdy bone, short leg...
# 70  The Cavalier’s all-around beauty, regal grace,...
# 72  Ceskys are muscular, short-legged, and handsom...
# 73  Chessies are strong, powerfully built gundogs ...
# 74  The Chihuahua is a balanced, graceful dog of t...
# 75  The Chinese Crested, a lively and alert toy br...
# 76  The compact, medium-sized Chinese Shar-Pei is ...
# 77  Tawny-coated, no-frills Chinooks are muscular ...
# 78  Chows are powerful, compactly built dogs stand...
# 79  Standing under 20 inches, the Cirneco (“cheer-...
# 80  Clumber Spaniels are powerful bird dogs of hea...
#
#                                   temperament popularity  min_height  \
# 0         Confident, Famously Funny, Fearless        148       22.86
# 1   Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2                Friendly, Clever, Courageous         60       58.42
# 3     Courageous, Dignified, Profoundly Loyal         47       60.96
# 4                Affectionate, Loyal, Playful         58       58.42
# 6                     Sweet, Mellow, Sociable        175       58.42
# 7                       Playful, Perky, Smart        122       22.86
# 8     Independent, Easy-Going, Sweet-Tempered        186       53.34
# 11             Confident, Smart, Good-Natured         85       43.18
# 12                     Eager, Happy, Charming        166       38.10
# 13               Loyal, Independent, Reserved         90       68.58
# 15                   Alert, Curious, Pleasant         55       43.18
# 17            Smart, Work-Oriented, Exuberant         17       45.72
# 19         Affectionate, Courageous, Spirited        140       25.40
# 20    Loyal, Independent, Deeply Affectionate         of       59.69
# 21            Friendly, Bright, Sweet-Natured         of       48.26
# 22                 Independent, Smart, Poised         87       40.64
# 24                 Charming, Patient, Low-Key         39       38.10
# 26                   Friendly, Curious, Merry          6       33.02
# 27                 Smart, Bouncy, Charismatic        127       50.80
# 28                 Gentle, Faithful, Obedient        124       60.96
# 31              Confident, Smart, Hardworking         43       55.88
# 32           Bright, Watchful, Serious-Minded        125       55.88
# 33             Courageous, Alert, Intelligent        106       55.88
# 34         Independent, Sociable, Intelligent        187       55.88
# 35             Loyal, Good-Natured, Observant        144       54.61
# 36                 Good-Natured, Calm, Strong         22       58.42
# 37                    Playful, Curious, Peppy         46       24.13
# 39                  Easy-Going, Bright, Brave        138       58.42
# 40                Intelligent, Calm, Powerful        118       66.04
# 41         Friendly, Independent, Inquisitive         49       58.42
# 42                  Smart, Devoted, Tenacious        130       53.34
# 43               Confident, Intelligent, Calm        121       55.88
# 46             Affectionate, Smart, Energetic         35       45.72
# 47                Affectionate, Happy, Plucky         88       30.48
# 48     Affectionate, Loyal, Regally Dignified        103       66.04
# 49                  Friendly, Bright, Amusing         21       38.10
# 50    Affectionate, Courageous, Strong-Willed         84       59.69
# 51                 Bright, Fun-Loving, Active         11       54.61
# 52                   Friendly, Eager, Lovable        100       35.56
# 56                 Confident, Smart, Faithful        132       55.88
# 57                 Bright, Fun-Loving, Upbeat         26       44.45
# 59                      Loyal, Alert, Curious         98       17.78
# 60             Playful, Charming, Mischievous         62       53.34
# 61                 Friendly, Courageous, Calm          5       35.56
# 62                 Affectionate, Loyal, Brave         51       60.96
# 63                      Alert, Cheerful, Busy         69       24.13
# 64                 Confident, Alert, Vigilant        179       48.26
# 65        Affectionate, Intelligent, Majestic         32       59.69
# 66                 Affectionate, Loyal, Smart         68       26.67
# 70             Affectionate, Gentle, Graceful         18       30.48
# 72       Clever, Adventurous, Family-Oriented        185       25.40
# 73            Affectionate, Bright, Sensitive         45       53.34
# 74                  Charming, Graceful, Sassy         33       12.70
# 75                Affectionate, Alert, Lively         79       27.94
# 76                   Loyal, Independent, Calm         64       45.72
# 77                    Smart, Patient, Devoted        190       55.88
# 78          Dignified, Bright, Serious-Minded         75       43.18
# 79        Affectionate, Friendly, Independent        183       41.91
# 80               Mellow, Amusing, Gentlemanly        143       43.18
#
#     max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0        29.21    3.175147    4.535924            12.0            15.0  ...
# 1        68.58   22.679619   27.215542            12.0            15.0  ...
# 2        58.42   22.679619   31.751466            11.0            14.0  ...
# 3        71.12   31.751466   58.967008            10.0            13.0  ...
# 4        63.50   34.019428   38.555351            10.0            14.0  ...
# 6        66.04   20.411657   29.483504            11.0            12.0  ...
# 7        48.26    2.721554   15.875733            13.0            15.0  ...
# 8        63.50   27.215542   31.751466            11.0            13.0  ...
# 11       48.26   18.143695   31.751466            12.0            16.0  ...
# 12       45.72   11.339809   20.411657            10.0            14.0  ...
# 13       73.66   36.287390   68.038855            11.0            13.0  ...
# 15       50.80   15.875733   22.679619            12.0            16.0  ...
# 17       58.42   18.143695   29.483504            12.0            15.0  ...
# 19       27.94    6.803886    9.071847            11.0            15.0  ...
# 20       73.66   14.968548   24.947580            12.0            15.0  ...
# 21       62.23   15.875733   29.483504            12.0            14.0  ...
# 22       43.18    9.979032   10.886217            13.0            14.0  ...
# 24       38.10   18.143695   29.483504            12.0            13.0  ...
# 26       38.10    5.896701   13.607771            10.0            15.0  ...
# 27       55.88   20.411657   24.947580            12.0            14.0  ...
# 28       69.85   31.751466   49.895161            10.0            12.0  ...
# 31       66.04   18.143695   36.287390            14.0            16.0  ...
# 32       66.04   20.411657   34.019428            12.0            14.0  ...
# 33       66.04   20.411657   34.019428            12.0            14.0  ...
# 34       59.69   25.854765   38.101759            13.0            15.0  ...
# 35       64.77   22.679619   31.751466            12.0            13.0  ...
# 36       69.85   31.751466   52.163123             7.0            10.0  ...
# 37       29.21    5.443108    8.164663            14.0            15.0  ...
# 39       68.58   29.483504   49.895161            10.0            12.0  ...
# 40       76.20   36.287390   58.967008            10.0            12.0  ...
# 41       68.58   36.287390   49.895161            10.0            12.0  ...
# 42       68.58   20.411657   36.287390            11.0            12.0  ...
# 43       68.58   68.038855   90.718474             9.0            11.0  ...
# 46       55.88   13.607771   24.947580            12.0            15.0  ...
# 47       38.10    5.216312    7.030682            12.0            15.0  ...
# 48       71.12   27.215542   47.627199             9.0            14.0  ...
# 49       43.18    5.443108   11.339809            11.0            13.0  ...
# 50       69.85   31.751466   49.895161            10.0            12.0  ...
# 51       63.50    6.803886   36.287390            10.0            12.0  ...
# 52       45.72   11.339809   18.143695            10.0            15.0  ...
# 56       68.58   24.947580   45.359237            12.0            12.0  ...
# 57       52.07   13.607771   18.143695            12.0            14.0  ...
# 59       25.40    3.628739    4.535924            12.0            15.0  ...
# 60       55.88   22.679619   31.751466            12.0            13.0  ...
# 61       38.10   18.143695   22.679619             8.0            10.0  ...
# 62       68.58   45.359237   58.967008             7.0             9.0  ...
# 63       25.40    5.896701    6.350293            13.0            15.0  ...
# 64       60.96   15.875733   24.947580            12.0            15.0  ...
# 65       69.85    0.000000    0.000000             9.0            12.0  ...
# 66       31.75   11.339809   17.236510            12.0            15.0  ...
# 70       33.02    5.896701    8.164663            12.0            15.0  ...
# 72       33.02    6.350293   10.886217            12.0            15.0  ...
# 73       66.04   24.947580   36.287390            10.0            13.0  ...
# 74       20.32    2.721554    2.721554            14.0            16.0  ...
# 75       33.02    3.628739    5.443108            13.0            18.0  ...
# 76       50.80   20.411657   27.215542             8.0            12.0  ...
# 77       66.04   22.679619   40.823313            12.0            15.0  ...
# 78       50.80   20.411657   31.751466             8.0            12.0  ...
# 79       49.53    7.711070   11.793402            12.0            14.0  ...
# 80       50.80   24.947580   38.555351            10.0            12.0  ...
#
#    grooming_frequency_value  grooming_frequency_category shedding_value  \
# 0                       0.6    2-3 Times a Week Brushing            0.6
# 1                       0.8               Daily Brushing            0.2
# 2                       0.6    2-3 Times a Week Brushing            0.4
# 3                       0.8               Daily Brushing            0.6
# 4                       0.6    2-3 Times a Week Brushing            0.6
# 6                       0.2        Occasional Bath/Brush            0.4
# 7                       0.4              Weekly Brushing            0.6
# 8                       0.2        Occasional Bath/Brush            0.6
# 11                      0.2        Occasional Bath/Brush            0.4
# 12                      0.6    2-3 Times a Week Brushing            0.2
# 13                      0.4              Weekly Brushing            0.6
# 15                      0.2        Occasional Bath/Brush            0.8
# 17                      0.4              Weekly Brushing            0.6
# 19                      0.4              Weekly Brushing            0.2
# 20                      0.4              Weekly Brushing            0.4
# 21                      0.4              Weekly Brushing            0.2
# 22                      0.2        Occasional Bath/Brush            0.4
# 24                      0.6    2-3 Times a Week Brushing            0.4
# 26                      0.6    2-3 Times a Week Brushing            0.6
# 27                      0.8               Daily Brushing            0.6
# 28                      0.6    2-3 Times a Week Brushing            1.0
# 31                      0.4              Weekly Brushing            0.6
# 32                      0.6    2-3 Times a Week Brushing            0.6
# 33                      0.6    2-3 Times a Week Brushing            0.6
# 34                      0.2        Occasional Bath/Brush            0.2
# 35                      0.2        Occasional Bath/Brush            0.6
# 36                      0.6    2-3 Times a Week Brushing            1.0
# 37                      1.0       Specialty/Professional            0.2
# 39                      0.4              Weekly Brushing            0.6
# 40                      0.8               Daily Brushing            0.6
# 41                      0.4              Weekly Brushing            0.6
# 42                      0.4              Weekly Brushing            0.6
# 43                      0.2        Occasional Bath/Brush            0.4
# 46                      0.6    2-3 Times a Week Brushing            0.6
# 47                      0.4              Weekly Brushing            0.4
# 48                      0.4              Weekly Brushing            0.6
# 49                      0.4              Weekly Brushing            0.2
# 50                      0.8               Daily Brushing            0.6
# 51                      0.4              Weekly Brushing            0.4
# 52                      0.6    2-3 Times a Week Brushing            0.6
# 56                      0.8               Daily Brushing            0.2
# 57                      0.6    2-3 Times a Week Brushing            0.6
# 59                      0.6    2-3 Times a Week Brushing            0.6
# 60                      0.4              Weekly Brushing            0.6
# 61                      0.6    2-3 Times a Week Brushing            0.8
# 62                      0.2        Occasional Bath/Brush            0.6
# 63                      0.4              Weekly Brushing            0.4
# 64                      0.4              Weekly Brushing            1.0
# 65                      0.2        Occasional Bath/Brush            0.4
# 66                      0.4              Weekly Brushing            0.6
# 70                      0.4              Weekly Brushing            0.4
# 72                      0.4              Weekly Brushing            0.4
# 73                      0.6    2-3 Times a Week Brushing            0.8
# 74                      0.2        Occasional Bath/Brush            0.4
# 75                      0.2        Occasional Bath/Brush            0.2
# 76                      0.2        Occasional Bath/Brush            0.8
# 77                      0.4              Weekly Brushing            0.6
# 78                      0.6    2-3 Times a Week Brushing            0.6
# 79                      0.2        Occasional Bath/Brush            0.2
# 80                      0.4              Weekly Brushing            0.8
#
#     shedding_category energy_level_value   energy_level_category  \
# 0            Seasonal                0.6        Regular Exercise
# 1          Infrequent                0.8               Energetic
# 2          Occasional                0.6        Regular Exercise
# 3            Seasonal                0.8               Energetic
# 4            Seasonal                0.8               Energetic
# 6          Occasional                0.8               Energetic
# 7            Seasonal                0.8               Energetic
# 8            Seasonal                0.8               Energetic
# 11         Occasional                0.6        Regular Exercise
# 12         Infrequent                0.6        Regular Exercise
# 13           Seasonal                0.6        Regular Exercise
# 15          Regularly                1.0  Needs Lots of Activity
# 17           Seasonal                0.8               Energetic
# 19         Infrequent                0.8               Energetic
# 20         Occasional                0.6        Regular Exercise
# 21         Infrequent                0.6        Regular Exercise
# 22         Occasional                0.8               Energetic
# 24         Occasional                0.2            Couch Potato
# 26           Seasonal                0.8               Energetic
# 27           Seasonal                0.6        Regular Exercise
# 28           Frequent                1.0  Needs Lots of Activity
# 31           Seasonal                0.8               Energetic
# 32           Seasonal                0.8               Energetic
# 33           Seasonal                0.8               Energetic
# 34         Infrequent                0.4                    Calm
# 35           Seasonal                1.0  Needs Lots of Activity
# 36           Frequent                0.8               Energetic
# 37         Infrequent                0.6        Regular Exercise
# 39           Seasonal                0.6        Regular Exercise
# 40           Seasonal                0.8               Energetic
# 41           Seasonal                0.6        Regular Exercise
# 42           Seasonal                0.8               Energetic
# 43         Occasional                0.4                    Calm
# 46           Seasonal                1.0  Needs Lots of Activity
# 47         Occasional                0.6        Regular Exercise
# 48           Seasonal                0.8               Energetic
# 49         Infrequent                0.6        Regular Exercise
# 50           Seasonal                0.8               Energetic
# 51         Occasional                0.8               Energetic
# 52           Seasonal                0.6        Regular Exercise
# 56         Infrequent                0.6        Regular Exercise
# 57           Seasonal                1.0  Needs Lots of Activity
# 59           Seasonal                0.6        Regular Exercise
# 60           Seasonal                0.8               Energetic
# 61          Regularly                0.6        Regular Exercise
# 62           Seasonal                0.8               Energetic
# 63         Occasional                0.6        Regular Exercise
# 64           Frequent                0.6        Regular Exercise
# 65         Occasional                0.8               Energetic
# 66           Seasonal                0.8               Energetic
# 70         Occasional                0.4                    Calm
# 72         Occasional                0.6        Regular Exercise
# 73          Regularly                0.8               Energetic
# 74         Occasional                0.6        Regular Exercise
# 75         Infrequent                0.6        Regular Exercise
# 76          Regularly                0.6        Regular Exercise
# 77           Seasonal                0.8               Energetic
# 78           Seasonal                0.6        Regular Exercise
# 79         Infrequent                0.6        Regular Exercise
# 80          Regularly                0.6        Regular Exercise
#
#    trainability_value  trainability_category demeanor_value  \
# 0                 0.8          Easy Training            1.0
# 1                 0.2        May be Stubborn            0.2
# 2                 1.0        Eager to Please            0.8
# 3                 1.0        Eager to Please            0.6
# 4                 0.4            Independent            0.8
# 6                 0.6              Agreeable            0.6
# 7                 1.0        Eager to Please            1.0
# 8                 0.4            Independent            0.8
# 11                0.6              Agreeable            0.6
# 12                1.0        Eager to Please            0.8
# 13                0.4            Independent            0.4
# 15                0.2        May be Stubborn            0.4
# 17                1.0        Eager to Please            0.6
# 19                0.6              Agreeable            0.8
# 20                0.4            Independent            0.8
# 21                0.6              Agreeable            0.8
# 22                0.4            Independent            0.4
# 24                0.4            Independent            0.8
# 26                0.6              Agreeable            0.8
# 27                0.4            Independent            1.0
# 28                0.8          Easy Training            0.4
# 31                0.8          Easy Training            0.4
# 32                0.8          Easy Training            0.4
# 33                0.8          Easy Training            0.4
# 34                0.6              Agreeable            0.4
# 35                0.8          Easy Training            0.6
# 36                0.8          Easy Training            0.4
# 37                0.6              Agreeable            1.0
# 39                0.4            Independent            0.8
# 40                0.8          Easy Training            0.4
# 41                0.4            Independent            0.6
# 42                0.6              Agreeable            0.8
# 43                0.6              Agreeable            0.4
# 46                1.0        Eager to Please            0.4
# 47                0.8          Easy Training            0.8
# 48                0.4            Independent            0.6
# 49                1.0        Eager to Please            1.0
# 50                0.6              Agreeable            0.6
# 51                0.8          Easy Training            1.0
# 52                1.0        Eager to Please            0.6
# 56                0.4            Independent            0.4
# 57                1.0        Eager to Please            0.8
# 59                0.6              Agreeable            0.8
# 60                0.4            Independent            0.8
# 61                0.6              Agreeable            0.8
# 62                0.6              Agreeable            0.6
# 63                0.6              Agreeable            0.8
# 64                0.4            Independent            0.4
# 65                0.6              Agreeable            0.6
# 66                0.6              Agreeable            0.6
# 70                1.0        Eager to Please            0.8
# 72                0.6              Agreeable            0.4
# 73                0.6              Agreeable            0.4
# 74                0.4            Independent            0.6
# 75                0.6              Agreeable            0.8
# 76                0.2        May be Stubborn            0.4
# 77                1.0        Eager to Please            0.8
# 78                0.2        May be Stubborn            0.4
# 79                0.6              Agreeable            0.6
# 80                0.6              Agreeable            0.4
#
#           demeanor_category
# 0                  Outgoing
# 1                Aloof/Wary
# 2                  Friendly
# 3          Alert/Responsive
# 4                  Friendly
# 6          Alert/Responsive
# 7                  Outgoing
# 8                  Friendly
# 11         Alert/Responsive
# 12                 Friendly
# 13  Reserved with Strangers
# 15  Reserved with Strangers
# 17         Alert/Responsive
# 19                 Friendly
# 20                 Friendly
# 21                 Friendly
# 22  Reserved with Strangers
# 24                 Friendly
# 26                 Friendly
# 27                 Outgoing
# 28  Reserved with Strangers
# 31  Reserved with Strangers
# 32  Reserved with Strangers
# 33  Reserved with Strangers
# 34  Reserved with Strangers
# 35         Alert/Responsive
# 36  Reserved with Strangers
# 37                 Outgoing
# 39                 Friendly
# 40  Reserved with Strangers
# 41         Alert/Responsive
# 42                 Friendly
# 43  Reserved with Strangers
# 46  Reserved with Strangers
# 47                 Friendly
# 48         Alert/Responsive
# 49                 Outgoing
# 50         Alert/Responsive
# 51                 Outgoing
# 52         Alert/Responsive
# 56  Reserved with Strangers
# 57                 Friendly
# 59                 Friendly
# 60                 Friendly
# 61                 Friendly
# 62         Alert/Responsive
# 63                 Friendly
# 64  Reserved with Strangers
# 65         Alert/Responsive
# 66         Alert/Responsive
# 70                 Friendly
# 72  Reserved with Strangers
# 73  Reserved with Strangers
# 74         Alert/Responsive
# 75                 Friendly
# 76  Reserved with Strangers
# 77                 Friendly
# 78  Reserved with Strangers
# 79         Alert/Responsive
# 80  Reserved with Strangers
#
# [60 rows x 21 columns]

# %%
# Save the cleaned DataFrame to a new CSV file in the Resources folder
breed_df_cleaned.to_csv("Resources/akc-data-cleaned.csv", index=False)

print("Cleaned CSV file has been saved successfully.")
# Out:
# Cleaned CSV file has been saved successfully.
